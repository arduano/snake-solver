# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
 
 
# Creating dataset
np.random.seed(10)
data = np.random.normal(100, 20, 200)
 
fig = plt.figure(figsize = (10, 7))

 
# Creating plot
# plt.xscale('log', base=10)
# plt.xscale('linear')
plt.title("Board size = 60, Iterations = 100")
plt.boxplot([
	[198023, 219973, 241455],
	[201685, 219067, 236950],
	[286650, 325198, 368311],
	[1052360, 1092642, 1150431],
	[1044691, 1094538, 1133533]
], vert = 0, labels = [
	'Dynamic Hamiltonian (jitter = 10)',
	'Dynamic Hamiltonian (jitter = 1)',
	'Dynamic Hamiltonian',
	'Static Hamiltonian Cycle',
	'Zig-Zag'
]);

plt.show()



# Creating plot
# plt.xscale('log', base=10)
plt.title("Board size = 60, Iterations = 100")
plt.boxplot([
	[198023, 219973, 241455],
	[201685, 219067, 236950],
	[286650, 325198, 368311],
	[1052360, 1092642, 1150431],
	[1044691, 1094538, 1133533]
], vert = 0, labels = [
	'Dynamic Hamiltonian (jitter = 10)',
	'Dynamic Hamiltonian (jitter = 1)',
	'Dynamic Hamiltonian',
	'Static Hamiltonian Cycle',
	'Zig-Zag'
]);

plt.show()
